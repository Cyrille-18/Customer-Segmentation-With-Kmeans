# %% [markdown]
# ## 02-Data Cleaning
#
# This notebook loads the raw customer segmentation dataset, performs a quality assessment, and produces a cleaned version ready for feature engineering.

# %% [markdown]
# ### Imports
#
# All preprocessing logic is encapsulated in `src/preprocessing.py` to keep this notebook concise and reproducible.

# %%
import src.preprocessing as proc

# %% [markdown]
# ### 1. Load Raw Data
#
# Read the CSV from `data/raw/`. The dataset contains customer marketing attributes collected from a retail company.

# %%
customer_data = proc.load_data('../data/raw/customer_segmentation.csv')

# %% [markdown]
# ### 2. Quality Assessment
#
# A quick audit of the dataset's shape, missing values, and duplicates before any transformation.

# %%
proc.assess_quality(customer_data)
# Out:
# {'rows': 2240, 'columns': 29, 'missing_values': 24, 'duplicates': 0}

# %%
customer_data.info()
customer_data.head()
customer_data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# #### Observations
#
# - **2 240 rows, 29 columns** — no duplicates detected.
# - **`Income`** is the only column with missing values (24 out of 2 240, ~1%). These will be handled in the cleaning step (drops the 24 rows with missing).
# - `Education` and `Marital_Status` are stored as `object`, no encoding required at this stage. `Dt_Customer` is parsed to datetime in the cleaning step.

# %% [markdown]
# ### 3. Cleaning & Export
#
# `proc.clean_data()` applies the full cleaning pipeline: imputes missing `Income` values,and parses `Dt_Customer` to a datetime. The result is saved to `data/processed/` for use in the next notebook.

# %%
cleaned_customer_data = proc.clean_data(customer_data)
cleaned_customer_data.to_csv('../data/processed/customer_cleaned.csv', index=False)
